# %% [markdown]
# # Первичный анализ данных

# %% [markdown]
# ## Библиотеки

# %%
import pandas as pd
import ipyplot
import seaborn as sns

# %% [markdown]
# ## Загрузка данных

# %%
transactions = pd.read_csv('./data_prepared/transactions_train.csv', date_parser='t_dat', dtype={'article_id': str})
articles = pd.read_csv('./data_prepared/articles.csv', dtype={'article_id': str})
customers = pd.read_csv('./data_prepared/customers.csv')

# %% [markdown]
# ## articles

# %% [markdown]
# ### Самые ходовые товары

# %%
COUNT_TOP_ARTICLES = 12
top_articles = articles.sort_values(by='rating', ascending=False).head(COUNT_TOP_ARTICLES)['article_id'].to_list()

path_to_top_articles = [f'./data/images/{article[:3]}/{article}.jpg' for article in top_articles]
labels = articles.set_index('article_id').loc[top_articles]['section_name'].to_list()

# %%
ipyplot.plot_images(path_to_top_articles, labels, max_images=COUNT_TOP_ARTICLES, img_width=150, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PjgZrR3moABDJmXxfjqBTF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PjgZrR3moABDJmXxfjqBTF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PjgZrR3moABDJmXxfjqBTF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PjgZrR3moABDJmXxfjqBTF:checked ~ #ipyplot-html-viewer-textarea-PjgZrR3moABDJmXxfjqBTF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PjgZrR3moABDJmXxfjqBTF:checked + #ipyplot-html-viewer-label-PjgZrR3moABDJmXxfjqBTF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-PjgZrR3moABDJmXxfjqBTF">
#         <label id="ipyplot-html-viewer-label-PjgZrR3moABDJmXxfjqBTF" for="ipyplot-html-viewer-toggle-PjgZrR3moABDJmXxfjqBTF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-PjgZrR3moABDJmXxfjqBTF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-XRHCRyjn5UTeLLw9QPkJuv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-XRHCRyjn5UTeLLw9QPkJuv">
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-9pujzZkoyXRzmuwxebAawr" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Divided Collection</h4>
#             <img src="data/images/070/0706016001.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-9pujzZkoyXRzmuwxebAawr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-ZnaSqtbxvQaW7ek6TsXMLZ" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Divided Collection</h4>
#             <img src="data/images/070/0706016002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-ZnaSqtbxvQaW7ek6TsXMLZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-dRfGJoWLYyF2Lc7ewsonqN" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Nightwear, Socks & Tigh</h4>
#             <img src="data/images/037/0372860001.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-dRfGJoWLYyF2Lc7ewsonqN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-eXSvX7q2d8ZowxkdKWwcvt" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Everyday Basics</h4>
#             <img src="data/images/061/0610776002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-eXSvX7q2d8ZowxkdKWwcvt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-jXvEevtM3YXo3v7XVoSZSH" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Divided Complements Other</h4>
#             <img src="data/images/075/0759871002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-jXvEevtM3YXo3v7XVoSZSH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-LkRKTD5sCNYE54FMtBANV5" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Lingerie</h4>
#             <img src="data/images/046/0464297007.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-LkRKTD5sCNYE54FMtBANV5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-AiENExPpbt7pSJf8bGVoSs" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Nightwear, Socks & Tigh</h4>
#             <img src="data/images/037/0372860002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-AiENExPpbt7pSJf8bGVoSs">
#                 <span class="ipyplot-img-expand"/>
#         <style>
#         #ipyplot-imgs-container-div-XRHCRyjn5UTeLLw9QPkJuv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-XRHCRyjn5UTeLLw9QPkJuv">
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-9pujzZkoyXRzmuwxebAawr" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Divided Collection</h4>
#             <img src="data/images/070/0706016001.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-9pujzZkoyXRzmuwxebAawr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-ZnaSqtbxvQaW7ek6TsXMLZ" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Divided Collection</h4>
#             <img src="data/images/070/0706016002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-ZnaSqtbxvQaW7ek6TsXMLZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-dRfGJoWLYyF2Lc7ewsonqN" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Nightwear, Socks & Tigh</h4>
#             <img src="data/images/037/0372860001.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-dRfGJoWLYyF2Lc7ewsonqN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-eXSvX7q2d8ZowxkdKWwcvt" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Everyday Basics</h4>
#             <img src="data/images/061/0610776002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-eXSvX7q2d8ZowxkdKWwcvt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-jXvEevtM3YXo3v7XVoSZSH" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Divided Complements Other</h4>
#             <img src="data/images/075/0759871002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-jXvEevtM3YXo3v7XVoSZSH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-LkRKTD5sCNYE54FMtBANV5" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Lingerie</h4>
#             <img src="data/images/046/0464297007.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-LkRKTD5sCNYE54FMtBANV5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-AiENExPpbt7pSJf8bGVoSs" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Nightwear, Socks & Tigh</h4>
#             <img src="data/images/037/0372860002.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-AiENExPpbt7pSJf8bGVoSs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-a9fwfAPvZ7s4FFSLQk7ArF" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Womens Everyday Basics</h4>
#             <img src="data/images/061/0610776001.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-a9fwfAPvZ7s4FFSLQk7ArF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-SgNV7WgxNabb4sMtfYud7M" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Ladies Denim</h4>
#             <img src="data/images/039/0399223001.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-SgNV7WgxNabb4sMtfYud7M">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XRHCRyjn5UTeLLw9QPkJuv">
#         <div id="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv-gNuZg3xAX9W5JDq52CqX2n" class="ipyplot-content-div-XRHCRyjn5UTeLLw9QPkJuv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Divided Collection

# %%
ax = articles['index_name'].value_counts().plot(kind='bar', title='Number of products for different sections', label='Number of products')
ax.legend()

# %% [markdown]
# ### Корреляционная матрица

# %%
corr = articles.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Вывод__
#
# Чаще всего в магазине H&M покупают джинсы/штаны. И почти все приведенные товары - женские.
# В корреляционной матрице линейных зависимсотей не обнаружено.

# %% [markdown]
# ## customers

# %% [markdown]
# ### Распределение количества транзакиций на возрастные группы

# %%
ax = customers['age_group'].value_counts().plot(kind='bar', title='The number of transactions for each age group')
ax.legend()

# %% [markdown]
# ### Корреляционная матрица

# %%
corr = customers.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Вывод__
#
# Самая активная возрастная группа в магазине H&M - _YOUNG (18-44 года)_.
# В корреляционной матрице имеется очень сильная линейная зависимость между признаками Active и FN. Имеет смысл оставить только один признак.
